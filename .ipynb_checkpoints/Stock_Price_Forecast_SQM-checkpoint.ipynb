# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
ticker = "SQM"

# %%
data = yf.download(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = pd.DataFrame(data)
df
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 1993-09-21   2.580331   2.653359   2.507303   2.507303   1.021979  17419974
# 1993-09-22   2.555988   2.555988   2.507303   2.507303   1.021979   3319264
# 1993-09-23   2.507303   2.531646   2.507303   2.519474   1.026939   1261156
# 1993-09-24   2.507303   2.531646   2.507303   2.531646   1.031901    201292
# 1993-09-27   2.531646   2.568160   2.531646   2.555988   1.041822    316316
# ...               ...        ...        ...        ...        ...       ...
# 2023-05-24  70.820000  71.190002  68.199997  69.070000  69.070000   1352700
# 2023-05-25  69.050003  69.050003  65.400002  66.089996  66.089996   2575700
# 2023-05-26  66.459999  66.809998  65.809998  66.290001  66.290001   1154600
# 2023-05-30  67.559998  67.930000  65.769997  66.870003  66.870003   1373900
# 2023-05-31  66.050003  66.220001  63.950001  64.250000  64.250000   1153956
#
# [7477 rows x 6 columns]

# %%
plt.figure(figsize=(12, 8))
plt.plot(df["Adj Close"])
plt.title(f"{ticker} Adjusted Close Price")
plt.xlabel('Year')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
len(df)
# Out:
# 7477

# %%
q_80 = int(len(df) * .8)
q_90 = int(len(df) * .9)

# %%
y_train = df["Adj Close"].iloc[:q_80]
y_val = df["Adj Close"].iloc[q_80: q_90]
y_test = df["Adj Close"].iloc[q_90:]

# %%
y_train.plot(figsize = (12, 8))
y_val.plot()
y_test.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length = 8
batch_size = 1

# %%
generator = TimeseriesGenerator(y_train, y_train, length = length, batch_size = batch_size)

# %%
validation_generator = TimeseriesGenerator(y_val, y_val, length = length, batch_size = batch_size)

# %%
test_generator = TimeseriesGenerator(y_test, y_test, length = length, batch_size = batch_size)

# %%
es = EarlyStopping(monitor = "val_loss", patience = 5)

# %%
n_features = 1

# %%
m = Sequential()

m.add(LSTM(64, input_shape = (length, n_features), activation = "relu", return_sequences = False))

m.add(Dense(8, activation = "relu"))

m.add(Dense(1, activation = "linear"))

m.compile(optimizer = Adam(learning_rate = .0001), loss = "mse", metrics = ["mean_absolute_error"])

# %%
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
m.fit_generator(generator, epochs = 50, validation_data = validation_generator, callbacks = [es])
# Out:
# Epoch 1/50
# C:\Users\User\AppData\Local\Temp\ipykernel_1056\1446656313.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   m.fit_generator(generator, epochs = 50, validation_data = validation_generator, callbacks = [es])
# 5973/5973 [==============================] - 35s 5ms/step - loss: 5.1680 - mean_absolute_error: 0.7712 - val_loss: 1.1394 - val_mean_absolute_error: 0.7939
# Epoch 2/50
# 5973/5973 [==============================] - 30s 5ms/step - loss: 0.2516 - mean_absolute_error: 0.2771 - val_loss: 0.9542 - val_mean_absolute_error: 0.7220
# Epoch 3/50
# 5973/5973 [==============================] - 34s 6ms/step - loss: 0.2048 - mean_absolute_error: 0.2494 - val_loss: 0.8329 - val_mean_absolute_error: 0.6635
# Epoch 4/50
# 5973/5973 [==============================] - 31s 5ms/step - loss: 0.1775 - mean_absolute_error: 0.2306 - val_loss: 0.8363 - val_mean_absolute_error: 0.6760
# Epoch 5/50
# 5973/5973 [==============================] - 31s 5ms/step - loss: 0.1728 - mean_absolute_error: 0.2267 - val_loss: 0.7970 - val_mean_absolute_error: 0.6548
# Epoch 6/50
# 5973/5973 [==============================] - 29s 5ms/step - loss: 0.1640 - mean_absolute_error: 0.2197 - val_loss: 0.8255 - val_mean_absolute_error: 0.6851
# Epoch 7/50
# 5973/5973 [==============================] - 16s 3ms/step - loss: 0.1585 - mean_absolute_error: 0.2155 - val_loss: 0.8732 - val_mean_absolute_error: 0.7007
# Epoch 8/50
# 5973/5973 [==============================] - 23s 4ms/step - loss: 0.1545 - mean_absolute_error: 0.2099 - val_loss: 0.6891 - val_mean_absolute_error: 0.6099
# Epoch 9/50
# 5973/5973 [==============================] - 14s 2ms/step - loss: 0.1544 - mean_absolute_error: 0.2113 - val_loss: 0.9656 - val_mean_absolute_error: 0.7462
# Epoch 10/50
# 5973/5973 [==============================] - 13s 2ms/step - loss: 0.1465 - mean_absolute_error: 0.2039 - val_loss: 0.7390 - val_mean_absolute_error: 0.6365
# Epoch 11/50
# 5973/5973 [==============================] - 13s 2ms/step - loss: 0.1479 - mean_absolute_error: 0.2069 - val_loss: 0.7614 - val_mean_absolute_error: 0.6472
# Epoch 12/50
# 5973/5973 [==============================] - 13s 2ms/step - loss: 0.1439 - mean_absolute_error: 0.2041 - val_loss: 1.2352 - val_mean_absolute_error: 0.8708
# Epoch 13/50
# 5973/5973 [==============================] - 13s 2ms/step - loss: 0.1442 - mean_absolute_error: 0.2026 - val_loss: 0.7649 - val_mean_absolute_error: 0.6433

# %%
losses = pd.DataFrame(m.history.history)
losses.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:>

# %%
y_hat_train = m.predict(generator).flatten()
y_hat_train.shape
# Out:
# 5973/5973 [==============================] - 6s 897us/step
# (5973,)

# %%
y_train.shape
# Out:
# (5981,)

# %%
train_df = pd.DataFrame(data = {"Train Actuals": y_train.iloc[length:].values.flatten(), "Train Predictions": y_hat_train}, index = y_train.iloc[length:].index)
train_df.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
train_df.iloc[-100:].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
y_hat_val = m.predict(validation_generator).flatten()
# Out:
# 740/740 [==============================] - 1s 897us/step

# %%
val_df = pd.DataFrame(data = {"Validation Actuals": y_val.iloc[length:].values.flatten(), "Validation Predictions": y_hat_val}, index = y_val.iloc[length:].index)
val_df.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
val_df.iloc[-100:].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
y_hat_test = m.predict(test_generator).flatten()
# Out:
# 740/740 [==============================] - 1s 916us/step

# %%
test_df = pd.DataFrame(data = {"Test Actuals": y_test.iloc[length:].values.flatten(), "Test Predictions": y_hat_test}, index = y_test.iloc[length:].index)
test_df.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
test_df.iloc[-100:].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ax = train_df.plot(figsize = (12, 8))
val_df.plot(ax = ax)
test_df.plot(ax = ax)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Forecast

# %%
m = Sequential()

m.add(LSTM(64, input_shape = (length, n_features), activation = "relu", return_sequences = False))

m.add(Dense(8, activation = "relu"))

m.add(Dense(1, activation = "linear"))

m.compile(optimizer = Adam(learning_rate = .0001), loss = "mse", metrics = ["mean_absolute_error"])

# %%
full_generator = TimeseriesGenerator(df["Adj Close"], df["Adj Close"], length = length, batch_size = batch_size)

# %%
m.fit_generator(full_generator, epochs = es.stopped_epoch)
# Out:
# Epoch 1/12
# C:\Users\User\AppData\Local\Temp\ipykernel_1056\3418163387.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   m.fit_generator(full_generator, epochs = es.stopped_epoch)
# 7469/7469 [==============================] - 17s 2ms/step - loss: 31.3627 - mean_absolute_error: 1.6205
# Epoch 2/12
# 7469/7469 [==============================] - 16s 2ms/step - loss: 1.7334 - mean_absolute_error: 0.6439
# Epoch 3/12
# 7469/7469 [==============================] - 17s 2ms/step - loss: 1.4607 - mean_absolute_error: 0.5917
# Epoch 4/12
# 7469/7469 [==============================] - 18s 2ms/step - loss: 1.1764 - mean_absolute_error: 0.5343
# Epoch 5/12
# 7469/7469 [==============================] - 18s 2ms/step - loss: 1.2168 - mean_absolute_error: 0.5350
# Epoch 6/12
# 7469/7469 [==============================] - 15s 2ms/step - loss: 1.2587 - mean_absolute_error: 0.5524
# Epoch 7/12
# 7469/7469 [==============================] - 16s 2ms/step - loss: 1.1397 - mean_absolute_error: 0.5107
# Epoch 8/12
# 7469/7469 [==============================] - 15s 2ms/step - loss: 1.1490 - mean_absolute_error: 0.5187
# Epoch 9/12
# 7469/7469 [==============================] - 17s 2ms/step - loss: 1.0814 - mean_absolute_error: 0.5077
# Epoch 10/12
# 7469/7469 [==============================] - 18s 2ms/step - loss: 1.1124 - mean_absolute_error: 0.5087
# Epoch 11/12
# 7469/7469 [==============================] - 15s 2ms/step - loss: 1.0541 - mean_absolute_error: 0.4939
# Epoch 12/12
# 7469/7469 [==============================] - 17s 2ms/step - loss: 0.9770 - mean_absolute_error: 0.4692

# %%
y_forecast = []

first_eval_batch = df["Adj Close"][-length:].values
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(length):
    current_pred = m.predict(current_batch)[0]
    y_forecast.append(current_pred)
    current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis = 1)
# Out:
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
forecast_index = pd.date_range(start = df.index[-1], periods = length, freq = "B")

# %%
forecast_df = pd.DataFrame(data = y_forecast, index = forecast_index, columns = [f"{ticker} Price Forecast"])

# %%
ax = df["Adj Close"].iloc[-30:].plot(figsize = (12, 8))
forecast_df.plot(ax = ax)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(m, f"LSTM_for_{ticker}_Stock.png", show_shapes = True)

# %%
m.save(f"LSTM_for_{ticker}_Stock.h5")
