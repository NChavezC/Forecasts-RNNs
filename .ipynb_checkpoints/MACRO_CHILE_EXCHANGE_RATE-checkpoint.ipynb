# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests

# %%
api_key = '6feb8c26f0ebddbc4a47b6cfeac77054'
url = f'https://api.stlouisfed.org/fred/series/observations?series_id=LRUNTTTTCLM156N&api_key={api_key}&observation_start=1960-01-01&observation_end=2022-12-01&frequency=m&file_type=json'
response = requests.get(url)

# %%
json_data = response.json()

# %%
data = [(obs["date"], obs["value"]) for obs in json_data["observations"]]
df = pd.DataFrame(data, columns=["date", "Unemployment Rate Chile"])
df["date"] = pd.to_datetime(df["date"])
df["Unemployment Rate Chile"] = df["Unemployment Rate Chile"].astype("float")
df.index = df["date"]
df = df.drop("date", axis = 1)
df.dropna()
df
# Out:
#             Unemployment Rate Chile
# date
# 1986-01-01                13.540000
# 1986-02-01                13.350000
# 1986-03-01                12.660000
# 1986-04-01                12.540000
# 1986-05-01                12.570000
# ...                             ...
# 2022-08-01                 8.040024
# 2022-09-01                 7.968381
# 2022-10-01                 7.948823
# 2022-11-01                 7.862749
# 2022-12-01                 8.037244
#
# [444 rows x 1 columns]

# %%
plt.figure(figsize=(12, 8))
plt.plot(df['Unemployment Rate Chile'])
plt.title("Chile's Unemployment Rate")
plt.xlabel('Year')
plt.ylabel('Unemployment (Percentage of People older than 15)')
# Out:
# Text(0, 0.5, 'Unemployment (Percentage of People older than 15)')

# %%
len(df)
# Out:
# 444

# %%
q_80 = int(len(df) * .8)
q_90 = int(len(df) * .9)

# %%
y_train = df["Unemployment Rate Chile"].iloc[:q_80]
y_val = df["Unemployment Rate Chile"].iloc[q_80: q_90]
y_test = df["Unemployment Rate Chile"].iloc[q_90:]

# %%
y_train.plot(figsize = (12, 8))
y_val.plot()
y_test.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length = 18
batch_size = 1

# %%
generator = TimeseriesGenerator(y_train, y_train, length = length, batch_size = batch_size)

# %%
validation_generator = TimeseriesGenerator(y_val, y_val, length = length, batch_size = batch_size)

# %%
test_generator = TimeseriesGenerator(y_test, y_test, length = length, batch_size = batch_size)

# %%
es = EarlyStopping(monitor = "val_loss", patience = 5)

# %%
n_features = 1

# %%
m = Sequential()

m.add(LSTM(64, input_shape = (length, n_features), activation = "relu", return_sequences = False))

m.add(Dense(8, activation = "relu"))

m.add(Dense(1, activation = "linear"))

m.compile(optimizer = Adam(learning_rate = .0001), loss = "mse", metrics = ["mean_absolute_error"])

# %%
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
m.fit_generator(generator, epochs = 50, validation_data = validation_generator, callbacks = [es])
# Out:
# Epoch 1/50
# C:\Users\User\AppData\Local\Temp\ipykernel_4452\1446656313.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   m.fit_generator(generator, epochs = 50, validation_data = validation_generator, callbacks = [es])
# 337/337 [==============================] - 2s 4ms/step - loss: 22.2544 - mean_absolute_error: 3.5451 - val_loss: 0.4345 - val_mean_absolute_error: 0.5618
# Epoch 2/50
# 337/337 [==============================] - 1s 3ms/step - loss: 1.1106 - mean_absolute_error: 0.8104 - val_loss: 0.0825 - val_mean_absolute_error: 0.2467
# Epoch 3/50
# 337/337 [==============================] - 1s 3ms/step - loss: 0.7916 - mean_absolute_error: 0.6800 - val_loss: 0.0877 - val_mean_absolute_error: 0.2299
# Epoch 4/50
# 337/337 [==============================] - 1s 3ms/step - loss: 0.5911 - mean_absolute_error: 0.5705 - val_loss: 0.0623 - val_mean_absolute_error: 0.2141
# Epoch 5/50
# 337/337 [==============================] - 1s 3ms/step - loss: 0.3918 - mean_absolute_error: 0.4872 - val_loss: 0.3023 - val_mean_absolute_error: 0.4949
# Epoch 6/50
# 337/337 [==============================] - 1s 3ms/step - loss: 0.3253 - mean_absolute_error: 0.4294 - val_loss: 0.1073 - val_mean_absolute_error: 0.2743
# Epoch 7/50
# 337/337 [==============================] - 1s 3ms/step - loss: 0.3020 - mean_absolute_error: 0.4351 - val_loss: 0.0701 - val_mean_absolute_error: 0.2177
# Epoch 8/50
# 337/337 [==============================] - 1s 3ms/step - loss: 0.2336 - mean_absolute_error: 0.3693 - val_loss: 0.1072 - val_mean_absolute_error: 0.2784
# Epoch 9/50
# 337/337 [==============================] - 1s 3ms/step - loss: 0.1983 - mean_absolute_error: 0.3506 - val_loss: 0.0439 - val_mean_absolute_error: 0.1749
# Epoch 10/50
# 337/337 [==============================] - 1s 3ms/step - loss: 0.1858 - mean_absolute_error: 0.3465 - val_loss: 0.0833 - val_mean_absolute_error: 0.2425
# Epoch 11/50
# 337/337 [==============================] - 1s 3ms/step - loss: 0.1659 - mean_absolute_error: 0.3254 - val_loss: 0.0531 - val_mean_absolute_error: 0.1851
# Epoch 12/50
# 337/337 [==============================] - 1s 3ms/step - loss: 0.1772 - mean_absolute_error: 0.3389 - val_loss: 0.0485 - val_mean_absolute_error: 0.1803
# Epoch 13/50
# 337/337 [==============================] - 1s 3ms/step - loss: 0.1651 - mean_absolute_error: 0.3320 - val_loss: 0.1496 - val_mean_absolute_error: 0.3380
# Epoch 14/50
# 337/337 [==============================] - 1s 3ms/step - loss: 0.1520 - mean_absolute_error: 0.3088 - val_loss: 0.0597 - val_mean_absolute_error: 0.1995

# %%
losses = pd.DataFrame(m.history.history)
losses[["loss", "val_loss"]].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:>

# %%
y_hat_train = m.predict(generator).flatten()
# Out:
# 337/337 [==============================] - 1s 1ms/step

# %%
train_df = pd.DataFrame(data = {"Train Actuals": y_train.iloc[length:].values.flatten(), "Train Predictions": y_hat_train}, index = y_train.iloc[length:].index)
train_df.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
train_df.iloc[-100:].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
y_hat_val = m.predict(validation_generator).flatten()
# Out:
# 26/26 [==============================] - 0s 1ms/step

# %%
val_df = pd.DataFrame(data = {"Validation Actuals": y_val.iloc[length:].values.flatten(), "Validation Predictions": y_hat_val}, index = y_val.iloc[length:].index)
val_df.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
val_df.iloc[-100:].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
y_hat_test = m.predict(test_generator).flatten()
# Out:
# 27/27 [==============================] - 0s 1ms/step

# %%
test_df = pd.DataFrame(data = {"Test Actuals": y_test.iloc[length:].values.flatten(), "Test Predictions": y_hat_test}, index = y_test.iloc[length:].index)
test_df.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
test_df.iloc[-100:].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
ax = train_df.plot(figsize = (12, 8))
val_df.plot(ax = ax)
test_df.plot(ax = ax)
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Forecast

# %%
m = Sequential()

m.add(LSTM(64, input_shape = (length, n_features), activation = "relu", return_sequences = False))

m.add(Dense(8, activation = "relu"))

m.add(Dense(1, activation = "linear"))

m.compile(optimizer = Adam(learning_rate = .0001), loss = "mse", metrics = ["mean_absolute_error"])

# %%
full_generator = TimeseriesGenerator(df["Unemployment Rate Chile"], df["Unemployment Rate Chile"], length = length, batch_size = batch_size)

# %%
m.fit_generator(full_generator, epochs = es.stopped_epoch)
# Out:
# Epoch 1/13
# C:\Users\User\AppData\Local\Temp\ipykernel_4452\3418163387.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   m.fit_generator(full_generator, epochs = es.stopped_epoch)
# 426/426 [==============================] - 3s 3ms/step - loss: 11.2730 - mean_absolute_error: 2.2765
# Epoch 2/13
# 426/426 [==============================] - 1s 3ms/step - loss: 0.9752 - mean_absolute_error: 0.7370
# Epoch 3/13
# 426/426 [==============================] - 2s 4ms/step - loss: 0.5822 - mean_absolute_error: 0.5651
# Epoch 4/13
# 426/426 [==============================] - 1s 3ms/step - loss: 0.4087 - mean_absolute_error: 0.4801
# Epoch 5/13
# 426/426 [==============================] - 1s 3ms/step - loss: 0.3180 - mean_absolute_error: 0.4143
# Epoch 6/13
# 426/426 [==============================] - 1s 3ms/step - loss: 0.2648 - mean_absolute_error: 0.3898
# Epoch 7/13
# 426/426 [==============================] - 1s 3ms/step - loss: 0.2520 - mean_absolute_error: 0.3666
# Epoch 8/13
# 426/426 [==============================] - 1s 3ms/step - loss: 0.2557 - mean_absolute_error: 0.3758
# Epoch 9/13
# 426/426 [==============================] - 1s 3ms/step - loss: 0.2414 - mean_absolute_error: 0.3784
# Epoch 10/13
# 426/426 [==============================] - 1s 3ms/step - loss: 0.2285 - mean_absolute_error: 0.3531
# Epoch 11/13
# 426/426 [==============================] - 1s 3ms/step - loss: 0.1877 - mean_absolute_error: 0.3387
# Epoch 12/13
# 426/426 [==============================] - 1s 3ms/step - loss: 0.1859 - mean_absolute_error: 0.3344
# Epoch 13/13
# 426/426 [==============================] - 1s 3ms/step - loss: 0.1859 - mean_absolute_error: 0.3332

# %%
y_forecast = []

first_eval_batch = df["Unemployment Rate Chile"][-length:].values
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(length):
    current_pred = m.predict(current_batch)[0]
    y_forecast.append(current_pred)
    current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis = 1)
# Out:
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
forecast_index = pd.date_range(start = df.index[-1], periods = length, freq = "MS")

# %%
forecast_df = pd.DataFrame(data = y_forecast, index = forecast_index, columns = ["Unemployment Rate Chile Forecast"])

# %%
ax = df["Unemployment Rate Chile"].iloc[-30:].plot(figsize = (12, 8))
forecast_df.plot(ax = ax)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(m, f"LSTM_for_Unemployment_Rate_Chile.png", show_shapes = True)

# %%
m.save(f"LSTM_for_Unemployment_Rate_Chile.h5")
