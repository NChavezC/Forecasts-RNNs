# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
ticker = "BCH"

# %%
data = yf.download(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = pd.DataFrame(data)
df
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2002-08-02   4.476202   4.491531   4.476202   4.491531   1.634645   25441
# 2002-08-05   4.491531   4.491531   4.491531   4.491531   1.634645       0
# 2002-08-06   4.491531   4.491531   4.491531   4.491531   1.634645       0
# 2002-08-07   4.476202   4.752132   4.476202   4.752132   1.729488   12721
# 2002-08-08   4.798120   4.828779   4.782791   4.828779   1.757383    5219
# ...               ...        ...        ...        ...        ...     ...
# 2023-05-24  21.540001  21.540001  20.910000  21.350000  21.350000  110800
# 2023-05-25  21.500000  21.639999  21.340000  21.420000  21.420000   47600
# 2023-05-26  21.459999  21.469999  21.150000  21.340000  21.340000   84800
# 2023-05-30  21.309999  21.420000  20.900000  21.040001  21.040001   69700
# 2023-05-31  21.070000  20.940001  20.250000  20.360001  20.360001   59285
#
# [5243 rows x 6 columns]

# %%
plt.figure(figsize=(12, 8))
plt.plot(df["Adj Close"])
plt.title(f"{ticker} Adjusted Close Price")
plt.xlabel('Year')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
len(df)
# Out:
# 5243

# %%
q_80 = int(len(df) * .8)
q_90 = int(len(df) * .9)

# %%
y_train = df["Adj Close"].iloc[:q_80]
y_val = df["Adj Close"].iloc[q_80: q_90]
y_test = df["Adj Close"].iloc[q_90:]

# %%
y_train.plot(figsize = (12, 8))
y_val.plot()
y_test.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length = 8
batch_size = 1

# %%
generator = TimeseriesGenerator(y_train, y_train, length = length, batch_size = batch_size)

# %%
validation_generator = TimeseriesGenerator(y_val, y_val, length = length, batch_size = batch_size)

# %%
test_generator = TimeseriesGenerator(y_test, y_test, length = length, batch_size = batch_size)

# %%
es = EarlyStopping(monitor = "val_loss", patience = 5)

# %%
n_features = 1

# %%
m = Sequential()

m.add(LSTM(64, input_shape = (length, n_features), activation = "relu", return_sequences = False))

m.add(Dense(8, activation = "relu"))

m.add(Dense(1, activation = "linear"))

m.compile(optimizer = Adam(learning_rate = .0001), loss = "mse", metrics = ["mean_absolute_error"])

# %%
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
m.fit_generator(generator, epochs = 50, validation_data = validation_generator, callbacks = [es])
# Out:
# Epoch 1/50
# C:\Users\User\AppData\Local\Temp\ipykernel_9812\1446656313.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   m.fit_generator(generator, epochs = 50, validation_data = validation_generator, callbacks = [es])
# 4186/4186 [==============================] - 11s 2ms/step - loss: 10.0689 - mean_absolute_error: 1.0986 - val_loss: 0.7154 - val_mean_absolute_error: 0.6632
# Epoch 2/50
# 4186/4186 [==============================] - 10s 2ms/step - loss: 0.1726 - mean_absolute_error: 0.2923 - val_loss: 0.8027 - val_mean_absolute_error: 0.7109
# Epoch 3/50
# 4186/4186 [==============================] - 9s 2ms/step - loss: 0.1632 - mean_absolute_error: 0.2815 - val_loss: 0.7332 - val_mean_absolute_error: 0.6786
# Epoch 4/50
# 4186/4186 [==============================] - 10s 2ms/step - loss: 0.1535 - mean_absolute_error: 0.2750 - val_loss: 0.5189 - val_mean_absolute_error: 0.5542
# Epoch 5/50
# 4186/4186 [==============================] - 11s 3ms/step - loss: 0.1459 - mean_absolute_error: 0.2674 - val_loss: 0.5080 - val_mean_absolute_error: 0.5486
# Epoch 6/50
# 4186/4186 [==============================] - 12s 3ms/step - loss: 0.1434 - mean_absolute_error: 0.2639 - val_loss: 0.8307 - val_mean_absolute_error: 0.7493
# Epoch 7/50
# 4186/4186 [==============================] - 28s 7ms/step - loss: 0.1336 - mean_absolute_error: 0.2544 - val_loss: 0.4737 - val_mean_absolute_error: 0.5380
# Epoch 8/50
# 4186/4186 [==============================] - 37s 9ms/step - loss: 0.1219 - mean_absolute_error: 0.2460 - val_loss: 0.3958 - val_mean_absolute_error: 0.4837
# Epoch 9/50
# 4186/4186 [==============================] - 38s 9ms/step - loss: 0.1179 - mean_absolute_error: 0.2400 - val_loss: 0.8568 - val_mean_absolute_error: 0.7775
# Epoch 10/50
# 4186/4186 [==============================] - 38s 9ms/step - loss: 0.1079 - mean_absolute_error: 0.2293 - val_loss: 0.4030 - val_mean_absolute_error: 0.4927
# Epoch 11/50
# 4186/4186 [==============================] - 38s 9ms/step - loss: 0.1041 - mean_absolute_error: 0.2248 - val_loss: 0.3174 - val_mean_absolute_error: 0.4287
# Epoch 12/50
# 4186/4186 [==============================] - 20s 5ms/step - loss: 0.1010 - mean_absolute_error: 0.2206 - val_loss: 0.3376 - val_mean_absolute_error: 0.4385
# Epoch 13/50
# 4186/4186 [==============================] - 20s 5ms/step - loss: 0.0971 - mean_absolute_error: 0.2184 - val_loss: 0.2826 - val_mean_absolute_error: 0.3997
# Epoch 14/50
# 4186/4186 [==============================] - 24s 6ms/step - loss: 0.0953 - mean_absolute_error: 0.2181 - val_loss: 0.4019 - val_mean_absolute_error: 0.5076
# Epoch 15/50
# 4186/4186 [==============================] - 23s 6ms/step - loss: 0.0932 - mean_absolute_error: 0.2136 - val_loss: 0.2859 - val_mean_absolute_error: 0.4086
# Epoch 16/50
# 4186/4186 [==============================] - 12s 3ms/step - loss: 0.0922 - mean_absolute_error: 0.2104 - val_loss: 0.3023 - val_mean_absolute_error: 0.4224
# Epoch 17/50
# 4186/4186 [==============================] - 12s 3ms/step - loss: 0.0852 - mean_absolute_error: 0.2065 - val_loss: 0.2822 - val_mean_absolute_error: 0.4015
# Epoch 18/50
# 4186/4186 [==============================] - 12s 3ms/step - loss: 0.0855 - mean_absolute_error: 0.2046 - val_loss: 0.2458 - val_mean_absolute_error: 0.3670
# Epoch 19/50
# 4186/4186 [==============================] - 15s 4ms/step - loss: 0.0842 - mean_absolute_error: 0.2022 - val_loss: 0.2602 - val_mean_absolute_error: 0.3762
# Epoch 20/50
# 4186/4186 [==============================] - 34s 8ms/step - loss: 0.0821 - mean_absolute_error: 0.2015 - val_loss: 0.3649 - val_mean_absolute_error: 0.4837
# Epoch 21/50
# 4186/4186 [==============================] - 30s 7ms/step - loss: 0.0792 - mean_absolute_error: 0.1971 - val_loss: 0.2274 - val_mean_absolute_error: 0.3528
# Epoch 22/50
# 4186/4186 [==============================] - 28s 7ms/step - loss: 0.0769 - mean_absolute_error: 0.1931 - val_loss: 0.5380 - val_mean_absolute_error: 0.6260
# Epoch 23/50
# 4186/4186 [==============================] - 23s 6ms/step - loss: 0.0765 - mean_absolute_error: 0.1944 - val_loss: 0.2369 - val_mean_absolute_error: 0.3621
# Epoch 24/50
# 4186/4186 [==============================] - 28s 7ms/step - loss: 0.0763 - mean_absolute_error: 0.1929 - val_loss: 0.2125 - val_mean_absolute_error: 0.3429
# Epoch 25/50
# 4186/4186 [==============================] - 20s 5ms/step - loss: 0.0711 - mean_absolute_error: 0.1859 - val_loss: 0.2714 - val_mean_absolute_error: 0.4003
# Epoch 26/50
# 4186/4186 [==============================] - 31s 7ms/step - loss: 0.0719 - mean_absolute_error: 0.1877 - val_loss: 0.2189 - val_mean_absolute_error: 0.3492
# Epoch 27/50
# 4186/4186 [==============================] - 25s 6ms/step - loss: 0.0709 - mean_absolute_error: 0.1873 - val_loss: 0.2182 - val_mean_absolute_error: 0.3453
# Epoch 28/50
# 4186/4186 [==============================] - 21s 5ms/step - loss: 0.0704 - mean_absolute_error: 0.1847 - val_loss: 0.2112 - val_mean_absolute_error: 0.3421
# Epoch 29/50
# 4186/4186 [==============================] - 25s 6ms/step - loss: 0.0701 - mean_absolute_error: 0.1853 - val_loss: 0.2131 - val_mean_absolute_error: 0.3372
# Epoch 30/50
# 4186/4186 [==============================] - 23s 5ms/step - loss: 0.0683 - mean_absolute_error: 0.1837 - val_loss: 0.2039 - val_mean_absolute_error: 0.3300
# Epoch 31/50
# 4186/4186 [==============================] - 21s 5ms/step - loss: 0.0667 - mean_absolute_error: 0.1807 - val_loss: 0.3476 - val_mean_absolute_error: 0.4654
# Epoch 32/50
# 4186/4186 [==============================] - 20s 5ms/step - loss: 0.0691 - mean_absolute_error: 0.1841 - val_loss: 0.2199 - val_mean_absolute_error: 0.3492
# Epoch 33/50
# 4186/4186 [==============================] - 22s 5ms/step - loss: 0.0640 - mean_absolute_error: 0.1772 - val_loss: 0.2239 - val_mean_absolute_error: 0.3522
# Epoch 34/50
# 4186/4186 [==============================] - 21s 5ms/step - loss: 0.0680 - mean_absolute_error: 0.1806 - val_loss: 0.2072 - val_mean_absolute_error: 0.3375
# Epoch 35/50
# 4186/4186 [==============================] - 24s 6ms/step - loss: 0.0640 - mean_absolute_error: 0.1754 - val_loss: 0.2039 - val_mean_absolute_error: 0.3308

# %%
losses = pd.DataFrame(m.history.history)
losses.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:>

# %%
y_hat_train = m.predict(generator).flatten()
y_hat_train.shape
# Out:
# 4186/4186 [==============================] - 11s 2ms/step
# (4186,)

# %%
y_train.shape
# Out:
# (4194,)

# %%
train_df = pd.DataFrame(data = {"Train Actuals": y_train.iloc[length:].values.flatten(), "Train Predictions": y_hat_train}, index = y_train.iloc[length:].index)
train_df.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
train_df.iloc[-100:].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
y_hat_val = m.predict(validation_generator).flatten()
# Out:
# 516/516 [==============================] - 1s 2ms/step

# %%
val_df = pd.DataFrame(data = {"Validation Actuals": y_val.iloc[length:].values.flatten(), "Validation Predictions": y_hat_val}, index = y_val.iloc[length:].index)
val_df.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
val_df.iloc[-100:].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
y_hat_test = m.predict(test_generator).flatten()
# Out:
# 517/517 [==============================] - 3s 5ms/step

# %%
test_df = pd.DataFrame(data = {"Test Actuals": y_test.iloc[length:].values.flatten(), "Test Predictions": y_hat_test}, index = y_test.iloc[length:].index)
test_df.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
test_df.iloc[-100:].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ax = train_df.plot(figsize = (12, 8))
val_df.plot(ax = ax)
test_df.plot(ax = ax)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Forecast

# %%
m = Sequential()

m.add(LSTM(64, input_shape = (length, n_features), activation = "relu", return_sequences = False))

m.add(Dense(8, activation = "relu"))

m.add(Dense(1, activation = "linear"))

m.compile(optimizer = Adam(learning_rate = .0001), loss = "mse", metrics = ["mean_absolute_error"])

# %%
full_generator = TimeseriesGenerator(df["Adj Close"], df["Adj Close"], length = length, batch_size = batch_size)

# %%
m.fit_generator(full_generator, epochs = es.stopped_epoch)
# Out:
# Epoch 1/34
# C:\Users\User\AppData\Local\Temp\ipykernel_9812\3418163387.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   m.fit_generator(full_generator, epochs = es.stopped_epoch)
# 5235/5235 [==============================] - 28s 5ms/step - loss: 3.7450 - mean_absolute_error: 0.7387
# Epoch 2/34
# 5235/5235 [==============================] - 25s 5ms/step - loss: 0.1419 - mean_absolute_error: 0.2651
# Epoch 3/34
# 5235/5235 [==============================] - 28s 5ms/step - loss: 0.1089 - mean_absolute_error: 0.2321
# Epoch 4/34
# 5235/5235 [==============================] - 16s 3ms/step - loss: 0.0944 - mean_absolute_error: 0.2169
# Epoch 5/34
# 5235/5235 [==============================] - 17s 3ms/step - loss: 0.0873 - mean_absolute_error: 0.2069
# Epoch 6/34
# 5235/5235 [==============================] - 17s 3ms/step - loss: 0.0823 - mean_absolute_error: 0.1994
# Epoch 7/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0785 - mean_absolute_error: 0.1942
# Epoch 8/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0761 - mean_absolute_error: 0.1922
# Epoch 9/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0720 - mean_absolute_error: 0.1858
# Epoch 10/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0712 - mean_absolute_error: 0.1834
# Epoch 11/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0710 - mean_absolute_error: 0.1832
# Epoch 12/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0721 - mean_absolute_error: 0.1846
# Epoch 13/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0693 - mean_absolute_error: 0.1822
# Epoch 14/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0688 - mean_absolute_error: 0.1787
# Epoch 15/34
# 5235/5235 [==============================] - 12s 2ms/step - loss: 0.0682 - mean_absolute_error: 0.1778
# Epoch 16/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0683 - mean_absolute_error: 0.1791
# Epoch 17/34
# 5235/5235 [==============================] - 12s 2ms/step - loss: 0.0674 - mean_absolute_error: 0.1773
# Epoch 18/34
# 5235/5235 [==============================] - 14s 3ms/step - loss: 0.0669 - mean_absolute_error: 0.1760
# Epoch 19/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0686 - mean_absolute_error: 0.1785
# Epoch 20/34
# 5235/5235 [==============================] - 13s 2ms/step - loss: 0.0678 - mean_absolute_error: 0.1757
# Epoch 21/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0661 - mean_absolute_error: 0.1741
# Epoch 22/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0667 - mean_absolute_error: 0.1770
# Epoch 23/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0667 - mean_absolute_error: 0.1754
# Epoch 24/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0664 - mean_absolute_error: 0.1749
# Epoch 25/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0664 - mean_absolute_error: 0.1753
# Epoch 26/34
# 5235/5235 [==============================] - 12s 2ms/step - loss: 0.0657 - mean_absolute_error: 0.1732
# Epoch 27/34
# 5235/5235 [==============================] - 13s 3ms/step - loss: 0.0652 - mean_absolute_error: 0.1723
# Epoch 28/34
# 5235/5235 [==============================] - 10s 2ms/step - loss: 0.0652 - mean_absolute_error: 0.1731
# Epoch 29/34
# 5235/5235 [==============================] - 11s 2ms/step - loss: 0.0655 - mean_absolute_error: 0.1734
# Epoch 30/34
# 5235/5235 [==============================] - 12s 2ms/step - loss: 0.0654 - mean_absolute_error: 0.1730
# Epoch 31/34
# 5235/5235 [==============================] - 10s 2ms/step - loss: 0.0658 - mean_absolute_error: 0.1738
# Epoch 32/34
# 5235/5235 [==============================] - 9s 2ms/step - loss: 0.0650 - mean_absolute_error: 0.1719
# Epoch 33/34
# 5235/5235 [==============================] - 10s 2ms/step - loss: 0.0657 - mean_absolute_error: 0.1724
# Epoch 34/34
# 5235/5235 [==============================] - 10s 2ms/step - loss: 0.0648 - mean_absolute_error: 0.1721

# %%
y_forecast = []

first_eval_batch = df["Adj Close"][-length:].values
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(length):
    current_pred = m.predict(current_batch)[0]
    y_forecast.append(current_pred)
    current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis = 1)
# Out:
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
forecast_index = pd.date_range(start = df.index[-1], periods = length, freq = "B")

# %%
forecast_df = pd.DataFrame(data = y_forecast, index = forecast_index, columns = [f"{ticker} Price Forecast"])

# %%
ax = df["Adj Close"].iloc[-30:].plot(figsize = (12, 8))
forecast_df.plot(ax = ax)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(m, f"LSTM_for_{ticker}_Stock.png", show_shapes = True)

# %%
m.save(f"LSTM_for_{ticker}_Stock.h5")
