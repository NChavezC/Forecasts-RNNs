# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests

# %%
api_key = '6feb8c26f0ebddbc4a47b6cfeac77054'
url = f'https://api.stlouisfed.org/fred/series/observations?series_id=NAEXKP01CLQ657S&api_key={api_key}&observation_start=1960-01-01&observation_end=2022-12-01&frequency=q&file_type=json'
response = requests.get(url)

# %%
json_data = response.json()
# Out:
# {'realtime_start': '2023-05-31',
#  'realtime_end': '2023-05-31',
#  'observation_start': '1960-01-01',
#  'observation_end': '2022-12-01',
#  'units': 'lin',
#  'output_type': 1,
#  'file_type': 'json',
#  'order_by': 'observation_date',
#  'sort_order': 'asc',
#  'count': 107,
#  'offset': 0,
#  'limit': 100000,
#  'observations': [{'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1995-04-01',
#    'value': '2.75781485568091'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1995-07-01',
#    'value': '0.489260671064934'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1995-10-01',
#    'value': '1.83974152215744'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1996-01-01',
#    'value': '3.07925189478144'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1996-04-01',
#    'value': '1.18474617769826'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1996-07-01',
#    'value': '1.17162783165772'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1996-10-01',
#    'value': '1.32389858734705'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1997-01-01',
#    'value': '1.09445403207796'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1997-04-01',
#    'value': '2.34789632084928'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1997-07-01',
#    'value': '2.36916455537383'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1997-10-01',
#    'value': '2.04548283706862'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1998-01-01',
#    'value': '-0.405949577671468'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1998-04-01',
#    'value': '2.00230460730879'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1998-07-01',
#    'value': '-0.463898366173282'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1998-10-01',
#    'value': '-3.50828731190498'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1999-01-01',
#    'value': '-0.318760793660647'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1999-04-01',
#    'value': '0.273996438187387'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1999-07-01',
#    'value': '2.50327454460026'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '1999-10-01',
#    'value': '2.23536584307714'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2000-01-01',
#    'value': '0.370176255282944'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2000-04-01',
#    'value': '-0.0181661617203933'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2000-07-01',
#    'value': '1.50320677771761'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2000-10-01',
#    'value': '1.24974451788501'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2001-01-01',
#    'value': '1.12586150105003'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2001-04-01',
#    'value': '0.789490824933387'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2001-07-01',
#    'value': '-0.629860669314891'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2001-10-01',
#    'value': '0.93417743522356'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2002-01-01',
#    'value': '0.91596073809315'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2002-04-01',
#    'value': '-0.245208565498055'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2002-07-01',
#    'value': '0.646969979549474'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2002-10-01',
#    'value': '2.06484307990468'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2003-01-01',
#    'value': '0.945707504405038'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2003-04-01',
#    'value': '0.838950581067059'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2003-07-01',
#    'value': '0.655179760649071'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2003-10-01',
#    'value': '0.780432570967449'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2004-01-01',
#    'value': '2.46214495661923'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2004-04-01',
#    'value': '2.17974001554838'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2004-07-01',
#    'value': '2.8196384274899'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2004-10-01',
#    'value': '1.40796784269579'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2005-01-01',
#    'value': '-0.0381426978717576'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2005-04-01',
#    'value': '1.62208291111133'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2005-07-01',
#    'value': '2.32627958019087'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2005-10-01',
#    'value': '1.38958905863029'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2006-01-01',
#    'value': '0.852661661889683'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2006-04-01',
#    'value': '2.07614464390682'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2006-07-01',
#    'value': '1.30640817468974'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2006-10-01',
#    'value': '2.03867102074383'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2007-01-01',
#    'value': '0.952486997481059'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2007-04-01',
#    'value': '0.933992463867189'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2007-07-01',
#    'value': '0.14684620925472'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2007-10-01',
#    'value': '1.68240743402643'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2008-01-01',
#    'value': '2.56223541482454'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2008-04-01',
#    'value': '0.0599559030743955'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2008-07-01',
#    'value': '-0.846287345196746'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2008-10-01',
#    'value': '-0.972420419567428'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2009-01-01',
#    'value': '-0.815451483101166'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2009-04-01',
#    'value': '-0.596197472471966'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2009-07-01',
#    'value': '1.11519886033022'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2009-10-01',
#    'value': '1.23689424005468'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2010-01-01',
#    'value': '0.357802556318723'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2010-04-01',
#    'value': '3.42223800768847'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2010-07-01',
#    'value': '2.33297118790375'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2010-10-01',
#    'value': '1.23696195102759'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2011-01-01',
#    'value': '1.26304137050889'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2011-04-01',
#    'value': '1.40014801091408'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2011-07-01',
#    'value': '0.369208298120576'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2011-10-01',
#    'value': '1.91126713288082'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2012-01-01',
#    'value': '1.72499646894528'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2012-04-01',
#    'value': '1.52555979511748'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2012-07-01',
#    'value': '0.636799890835626'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2012-10-01',
#    'value': '0.692551958884134'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2013-01-01',
#    'value': '1.83607494978675'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2013-04-01',
#    'value': '0.788929388607615'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2013-07-01',
#    'value': '0.549037823864424'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2013-10-01',
#    'value': '0.454704754351927'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2014-01-01',
#    'value': '0.362729210346847'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2014-04-01',
#    'value': '0.649268431950644'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2014-07-01',
#    'value': '-0.470502909976439'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2014-10-01',
#    'value': '1.18464035892825'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2015-01-01',
#    'value': '0.743590719118983'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2015-04-01',
#    'value': '0.803965144262989'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2015-07-01',
#    'value': '-0.460249941627323'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2015-10-01',
#    'value': '0.808955228375544'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2016-01-01',
#    'value': '1.3175163102133'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2016-04-01',
#    'value': '-0.669148807239663'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2016-07-01',
#    'value': '0.558000277701125'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2016-10-01',
#    'value': '-0.0802645239423989'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2017-01-01',
#    'value': '-0.359838266326451'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2017-04-01',
#    'value': '1.02553397846856'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2017-07-01',
#    'value': '1.83866493568605'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2017-10-01',
#    'value': '0.790813977540278'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2018-01-01',
#    'value': '1.29780729156305'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2018-04-01',
#    'value': '1.10488963424983'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2018-07-01',
#    'value': '-0.431450965383406'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2018-10-01',
#    'value': '1.21958618525166'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2019-01-01',
#    'value': '-0.201966283406465'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2019-04-01',
#    'value': '1.08025089821338'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2019-07-01',
#    'value': '0.21256346601836'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2019-10-01',
#    'value': '-3.85342461014012'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2020-01-01',
#    'value': '2.02159695941184'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2020-04-01',
#    'value': '-12.7522859449048'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2020-07-01',
#    'value': '5.34236261727339'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2020-10-01',
#    'value': '6.80355398517723'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2021-01-01',
#    'value': '3.36354530254757'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2021-04-01',
#    'value': '1.65706105655247'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2021-07-01',
#    'value': '4.47655265517319'},
#   {'realtime_start': '2023-05-31',
#    'realtime_end': '2023-05-31',
#    'date': '2021-10-01',
#    'value': '1.82011012147763'}]}

# %%
data = [(obs["date"], obs["value"]) for obs in json_data["observations"]]
df = pd.DataFrame(data, columns=["date", "Growth Rate Chile"])
df["date"] = pd.to_datetime(df["date"])
df["Growth Rate Chile"] = df["Growth Rate Chile"].astype("float")
df.index = df["date"]
df = df.drop("date", axis = 1)
df.dropna()
df
# Out:
#             Growth Rate Chile
# date
# 1995-04-01           2.757815
# 1995-07-01           0.489261
# 1995-10-01           1.839742
# 1996-01-01           3.079252
# 1996-04-01           1.184746
# ...                       ...
# 2020-10-01           6.803554
# 2021-01-01           3.363545
# 2021-04-01           1.657061
# 2021-07-01           4.476553
# 2021-10-01           1.820110
#
# [107 rows x 1 columns]

# %%
plt.figure(figsize=(12, 8))
plt.plot(df['Growth Rate Chile'])
plt.title("Chile's Growth Rate")
plt.xlabel('Year')
plt.ylabel('Growth Rate (1 USD in CLP)')
# Out:
# Text(0, 0.5, 'Growth Rate (1 USD in CLP)')

# %%
len(df)
# Out:
# 107

# %%
q_80 = int(len(df) * .8)
q_90 = int(len(df) * .9)

# %%
y_train = df["Growth Rate Chile"].iloc[:q_80]
y_val = df["Growth Rate Chile"].iloc[q_80: q_90]
y_test = df["Growth Rate Chile"].iloc[q_90:]

# %%
y_train.plot(figsize = (12, 8))
y_val.plot()
y_test.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length = 6
batch_size = 1

# %%
generator = TimeseriesGenerator(y_train, y_train, length = length, batch_size = batch_size)

# %%
validation_generator = TimeseriesGenerator(y_val, y_val, length = length, batch_size = batch_size)

# %%
test_generator = TimeseriesGenerator(y_test, y_test, length = length, batch_size = batch_size)

# %%
es = EarlyStopping(monitor = "val_loss", patience = 5)

# %%
n_features = 1

# %%
m = Sequential()

m.add(LSTM(64, input_shape = (length, n_features), activation = "relu", return_sequences = False))

m.add(Dense(8, activation = "relu"))

m.add(Dense(1, activation = "linear"))

m.compile(optimizer = Adam(learning_rate = .0001), loss = "mse", metrics = ["mean_absolute_error"])

# %%
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
m.fit_generator(generator, epochs = 50, validation_data = validation_generator, callbacks = [es])
# Out:
# Epoch 1/50
# C:\Users\User\AppData\Local\Temp\ipykernel_7568\1446656313.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   m.fit_generator(generator, epochs = 50, validation_data = validation_generator, callbacks = [es])
# 79/79 [==============================] - 2s 10ms/step - loss: 1.9994 - mean_absolute_error: 1.1806 - val_loss: 0.8492 - val_mean_absolute_error: 0.8406
# Epoch 2/50
# 79/79 [==============================] - 0s 3ms/step - loss: 1.8317 - mean_absolute_error: 1.1262 - val_loss: 0.7855 - val_mean_absolute_error: 0.8308
# Epoch 3/50
# 79/79 [==============================] - 0s 3ms/step - loss: 1.6763 - mean_absolute_error: 1.0638 - val_loss: 0.7233 - val_mean_absolute_error: 0.8195
# Epoch 4/50
# 79/79 [==============================] - 0s 3ms/step - loss: 1.5203 - mean_absolute_error: 1.0039 - val_loss: 0.6801 - val_mean_absolute_error: 0.8095
# Epoch 5/50
# 79/79 [==============================] - 0s 3ms/step - loss: 1.3833 - mean_absolute_error: 0.9405 - val_loss: 0.6486 - val_mean_absolute_error: 0.7974
# Epoch 6/50
# 79/79 [==============================] - 0s 3ms/step - loss: 1.2799 - mean_absolute_error: 0.8718 - val_loss: 0.6448 - val_mean_absolute_error: 0.7891
# Epoch 7/50
# 79/79 [==============================] - 0s 3ms/step - loss: 1.2229 - mean_absolute_error: 0.8439 - val_loss: 0.6516 - val_mean_absolute_error: 0.7840
# Epoch 8/50
# 79/79 [==============================] - 0s 3ms/step - loss: 1.1979 - mean_absolute_error: 0.8213 - val_loss: 0.6638 - val_mean_absolute_error: 0.7795
# Epoch 9/50
# 79/79 [==============================] - 0s 3ms/step - loss: 1.1902 - mean_absolute_error: 0.8071 - val_loss: 0.6773 - val_mean_absolute_error: 0.7756
# Epoch 10/50
# 79/79 [==============================] - 0s 3ms/step - loss: 1.1830 - mean_absolute_error: 0.8081 - val_loss: 0.6698 - val_mean_absolute_error: 0.7763
# Epoch 11/50
# 79/79 [==============================] - 0s 3ms/step - loss: 1.1781 - mean_absolute_error: 0.8046 - val_loss: 0.6716 - val_mean_absolute_error: 0.7753

# %%
losses = pd.DataFrame(m.history.history)
losses[["loss", "val_loss"]].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:>

# %%
y_hat_train = m.predict(generator).flatten()
# Out:
# 79/79 [==============================] - 0s 1ms/step

# %%
train_df = pd.DataFrame(data = {"Train Actuals": y_train.iloc[length:].values.flatten(), "Train Predictions": y_hat_train}, index = y_train.iloc[length:].index)
train_df.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
train_df.iloc[-100:].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
y_hat_val = m.predict(validation_generator).flatten()
# Out:
# 5/5 [==============================] - 0s 1ms/step

# %%
val_df = pd.DataFrame(data = {"Validation Actuals": y_val.iloc[length:].values.flatten(), "Validation Predictions": y_hat_val}, index = y_val.iloc[length:].index)
val_df.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
val_df.iloc[-100:].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
y_hat_test = m.predict(test_generator).flatten()
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
test_df = pd.DataFrame(data = {"Test Actuals": y_test.iloc[length:].values.flatten(), "Test Predictions": y_hat_test}, index = y_test.iloc[length:].index)
test_df.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
test_df.iloc[-100:].plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
ax = train_df.plot(figsize = (12, 8))
val_df.plot(ax = ax)
test_df.plot(ax = ax)
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Forecast

# %%
m = Sequential()

m.add(LSTM(64, input_shape = (length, n_features), activation = "relu", return_sequences = False))

m.add(Dense(8, activation = "relu"))

m.add(Dense(1, activation = "linear"))

m.compile(optimizer = Adam(learning_rate = .0001), loss = "mse", metrics = ["mean_absolute_error"])

# %%
full_generator = TimeseriesGenerator(df["Growth Rate Chile"], df["Growth Rate Chile"], length = length, batch_size = batch_size)

# %%
m.fit_generator(full_generator, epochs = es.stopped_epoch)
# Out:
# Epoch 1/10
# C:\Users\User\AppData\Local\Temp\ipykernel_7568\3418163387.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   m.fit_generator(full_generator, epochs = es.stopped_epoch)
# 101/101 [==============================] - 2s 3ms/step - loss: 4.5267 - mean_absolute_error: 1.4266
# Epoch 2/10
# 101/101 [==============================] - 0s 2ms/step - loss: 4.3373 - mean_absolute_error: 1.3754
# Epoch 3/10
# 101/101 [==============================] - 0s 2ms/step - loss: 4.1819 - mean_absolute_error: 1.3277
# Epoch 4/10
# 101/101 [==============================] - 0s 2ms/step - loss: 4.0383 - mean_absolute_error: 1.2802
# Epoch 5/10
# 101/101 [==============================] - 0s 2ms/step - loss: 3.9093 - mean_absolute_error: 1.2297
# Epoch 6/10
# 101/101 [==============================] - 0s 3ms/step - loss: 3.7925 - mean_absolute_error: 1.1775
# Epoch 7/10
# 101/101 [==============================] - 0s 3ms/step - loss: 3.6851 - mean_absolute_error: 1.1441
# Epoch 8/10
# 101/101 [==============================] - 0s 4ms/step - loss: 3.6248 - mean_absolute_error: 1.1222
# Epoch 9/10
# 101/101 [==============================] - 0s 3ms/step - loss: 3.5872 - mean_absolute_error: 1.1087
# Epoch 10/10
# 101/101 [==============================] - 0s 3ms/step - loss: 3.5733 - mean_absolute_error: 1.0993

# %%
y_forecast = []

first_eval_batch = df["Growth Rate Chile"][-length:].values
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(length):
    current_pred = m.predict(current_batch)[0]
    y_forecast.append(current_pred)
    current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis = 1)
# Out:
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
forecast_index = pd.date_range(start = df.index[-1], periods = length, freq = "QS")

# %%
forecast_df = pd.DataFrame(data = y_forecast, index = forecast_index, columns = ["Growth Rate Chile Forecast"])

# %%
ax = df["Growth Rate Chile"].iloc[-30:].plot(figsize = (12, 8))
forecast_df.plot(ax = ax)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(m, f"LSTM_for_Growth_Rate_Chile.png", show_shapes = True)

# %%
m.save(f"LSTM_for_Growth_Rate_Chile.h5")
